# %%
import seaborn as sns

# %%
#seaborn contain lot of data set inside it ,we here fetching tip dataset from seaborn
df=sns.load_dataset("tips")

# %%
df.shape
# Out:
# (244, 7)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#supervised machine learning

# %%
#--->#correlatin 
#its the relatin between dependent variable and independent variable or realation between dependent variable
#in here corellation only occur integer and floating type not string

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# corr --> -1 for negative cor and +1 postively core



#heat map
df=sns.load_dataset('titanic')
sns.heatmap(df.corr())
df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
#it is a heat map in here diagonaly vann kedkunth value 1 ann ie in white box the value 1
#alone value negative ayond a y axix - value mark chaithekunth

# %%
#3d plot vare nmk visulaize chaim pattum,histogram 1 d analysis
#2d analysis is also called byvarirate analysis
#multi feature analysis visualization help by sea born

# %%
## JoinPlot

#A join plot allows to study the relationship between 2 numeric variables. The central chart display their correlation. It is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot
### Bivariate Analysis

# %%
#join plot in seaborn
df=sns.load_dataset("tips")
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
#in above top graph show tip and left shoe total_bill

# %%
#pair plot more than one feature
sns.pairplot(df)

# %%
sns.distplot(df['tip'],kde=False,bins=10) # kernel density estimate.
# Out:
# c:\Users\arjunkurup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %%
#hue nmk string use chaim it show yes no i graph for eg soke it show yes in one color who use smoke and no in one color
#smoker example
sns.pairplot(df,hue='smoker')
